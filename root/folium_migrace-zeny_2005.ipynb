# %%
### Zdroje |/| Sources
# https://python-visualization.github.io/folium/index.html
# https://vverde.github.io/blob/interactivechoropleth.html
# https://nbviewer.jupyter.org/gist/talbertc-usgs/18f8901fc98f109f2b71156cf3ac81cd
# NOT USED though https://geospatialawarenesshub.com/blog/make-interactive-choropleth-maps/
# Nacti knihovny |/| Read the libraries
import folium
import folium.plugins as plugins
import pandas as pd
import geopandas as gpd

# %%
# Nastav proměnné pro (geo)json|/| Set variables for (geo)json
geo01 = "countries.geojson"
geo02 = "custom.geo.json"
# Načit data |/| Read data
dataabcmigracefinal = pd.read_csv("data-abc-migracefinal.csv", encoding="utf-8")
dataagemigracefinal = pd.read_csv("data-age-migracefinal.csv", encoding="utf-8")
datadestorigmigracefinal = pd.read_csv("data-dest_orig-migracefinal.csv", encoding="utf-8")
data1=dataabcmigracefinal
data2=dataagemigracefinal
data3=datadestorigmigracefinal
# Načti ještě jeden soubor pro HOVER fci |/| Read one more file for HOVER fct
geo = gpd.read_file(geo02)
### Extra spojeni |/| Extra connection
spojeni = gpd.pd.merge(geo, dataabcmigracefinal, left_on="adm0_a3", right_on="iso_3")

# %%
### Stanoveni kategorii |/| Choosing the categories
# Use https://colorbrewer2.org/#type=sequential&scheme=YlGnBu&n=5
import mapclassify as mc
t1 = "T1990"
t2 = "T1995"
t3 = "T2000" 
t4 = "T2005"
t5 = "T2010"
t6 = "T2015"
t7 = "T2019"
m1 = "M1990"
m2 = "M1995"
m3 = "M2000"
m4 = "M2005"
m5 = "M2010"
m6 = "M2015"
m7 = "M2019"
f1 = "F1990"
f2 = "F1995"
f3 = "F2000"
f4 = "F2005"
f5 = "F2010"
f6 = "F2015"
f7 = "F2019"
t1out = mc.NaturalBreaks(data1[t1], k=5)
t2out = mc.NaturalBreaks(data1[t2], k=5)
t3out = mc.NaturalBreaks(data1[t3], k=5)
t4out = mc.NaturalBreaks(data1[t4], k=5)
t5out = mc.NaturalBreaks(data1[t5], k=5)
t6out = mc.NaturalBreaks(data1[t6], k=5)
t7out = mc.NaturalBreaks(data1[t7], k=5)
m1out = mc.NaturalBreaks(data1[m1], k=5)
m2out = mc.NaturalBreaks(data1[m2], k=5)
m3out = mc.NaturalBreaks(data1[m3], k=5)
m4out = mc.NaturalBreaks(data1[m4], k=5)
m5out = mc.NaturalBreaks(data1[m5], k=5)
m6out = mc.NaturalBreaks(data1[m6], k=5)
m7out = mc.NaturalBreaks(data1[m7], k=5)
f1out = mc.NaturalBreaks(data1[f1], k=5)
f2out = mc.NaturalBreaks(data1[f2], k=5)
f3out = mc.NaturalBreaks(data1[f3], k=5)
f4out = mc.NaturalBreaks(data1[f4], k=5)
f5out = mc.NaturalBreaks(data1[f5], k=5)
f6out = mc.NaturalBreaks(data1[f6], k=5)
f7out = mc.NaturalBreaks(data1[f7], k=5)
# print(t1out)
# print(t2out)
# print(t3out)
# print(t4out)
# print(t5out)
# print(t6out)
# print(t7out)
# print(m1out)
# print(m2out)
# print(m3out)
# print(m4out)
# print(m5out)
# print(m6out)
# print(m7out)
# print(f1out)
# print(f2out)
# print(f3out)
# print(f4out)
# print(f5out)
# print(f6out)
# print(f7out)

# %%
t1kat = [0,600000,2500000,7500000,12000000,25000000]
t2kat = [0,700000,3250000,7500000,12000000,30000000]
t3kat = [0,850000,3000000,6500000,12000000,35000000]
t4kat = [0,1000000,3300000,7000000,12000000,40000000]
t5kat = [0,1100000,4000000,7500000,12000000,45000000]
t6kat = [0,1250000,4500000,8500000,12000000,50000000]
t7kat = [0,1250000,4500000,10000000,15000000,55000000]
m1kat = [0,450000,2000000,4000000,6000000,15000000]
m2kat = [0,350000,1300000,2600000,6000000,15000000]
m3kat = [0,400000,1500000,4000000,6000000,20000000]
m4kat = [0,450000,1500000,4000000,6000000,20000000]
m5kat = [0,450000,2000000,4000000,6000000,25000000]
m6kat = [0,550000,2000000,4000000,6000000,25000000]
m7kat = [0,800000,2400000,4200000,8000000,25000000]
f1kat = [0,350000,1125000,3000000,6000000,12000000]
f2kat = [0,350000,1500000,3750000,6500000,15000000]
f3kat = [0,450000,1750000,3250000,6000000,20000000]
f4kat = [0,500000,1750000,3500000,6000000,20000000]
f5kat = [0,600000,2000000,4000000,6000000,25000000]
f6kat = [0,750000,2150000,4500000,6000000,25000000]
f7kat = [0,700000,2500000,4500000,6500000,30000000]

# %%
##### KATEGORIE start
# myscale = (data1['T1990'].quantile((0,0.1,0.75,0.9,0.98,1))).tolist()
kategorie = f4kat
##### KATEGORIE stop

mapa = folium.Map(location=[0,0], zoom_start=2, control_scale=True)

### Definujeme první vrstvu |/| Define first layer
folium.Choropleth(
    geo_data=geo01,
    name="Ženy cizinky | 2005",
    data=data1,
    columns=["iso_3","F2005"],
    key_on="feature.properties.ISO_A3",
    fill_color="YlGnBu",
    fill_opacity=1,
    line_opacity=0.2,
#     legend_name="Cizinci celkem | 1990",
    nan_fill_color="#d9d9d9",
    overlay=True,
#     treshhold_scale=myscale
    bins=kategorie
).add_to(mapa)
###

### Definujeme druhou vrstvu |/| Define second layer
# folium.Choropleth(
#     geo_data=geo01,
#     name="Cizinci celkem | 2019",
#     data=data1,
#     columns=["iso_3","T2019"],
#     key_on="feature.properties.ISO_A3",
#     fill_color="YlGnBu",
#     fill_opacity=1,
#     line_opacity=0.2,
#     legend_name="Cizinci celkem | 2019",
#     nan_fill_color="#d9d9d9",
#     overlay=True,
# #     treshhold_scale=myscale,
#     bins=kat
# ).add_to(mapa)
###

### Přidání dalších podkladových map |/| Adding other base maps
folium.TileLayer('openstreetmap').add_to(mapa)
folium.TileLayer('stamentoner').add_to(mapa)
folium.TileLayer('stamenTerrain').add_to(mapa)
folium.TileLayer('stamenwatercolor').add_to(mapa)
folium.TileLayer('cartodbpositron').add_to(mapa)
folium.TileLayer('cartodbdark_matter').add_to(mapa)
###
folium.LayerControl().add_to(mapa)
##### HOVER STYLE
style_function = lambda x: {'fillColor': '#ffffff', 'color':'#000000', 'fillOpacity': 0.1, 'weight': 0.1}
highlight_function = lambda x: {'fillColor': '#000000', 'color':'#000000', 'fillOpacity': 0.50, 'weight': 0.1}
##### HOVER start
hover = folium.features.GeoJson(
    spojeni,
    style_function=style_function, 
    control=False,
    highlight_function=highlight_function, 
    tooltip=folium.features.GeoJsonTooltip(
        localize=True,
        fields=['country_en','F2005'],
        aliases=['Název: ','Počet žen (cizinek).: '],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;")))
# Přidej hover funkci a nastav ji prioritu do popředí |/| Add hover function and set it as a front priority
mapa.add_child(hover)
mapa.keep_in_front(hover)
##### HOVER end
### MINIMAP
minimap = plugins.MiniMap()
mapa.add_child(minimap)
### MINIMAP end
########## EXTRA LEGEND start
from branca.element import Template, MacroElement
template = """
{% macro html(this, kwargs) %}
<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">
  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});
  </script>
</head>
<body>
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; left: 10px; bottom: 50px;'>
<div class='legend-title'>Cizinky zeny | 2005 </div>
<div class='legend-scale'>
  <ul class='legend-labels'>
<li><span style='background:#ffffcc;opacity:0.7;'></span>500 000</li>
<li><span style='background:#a1dab4;opacity:0.7;'></span>1 750 000</li>
<li><span style='background:#41b6c4;opacity:0.7;'></span>3 500 000</li>
<li><span style='background:#2c7fb8;opacity:0.7;'></span>6 000 000</li>
<li><span style='background:#253494;opacity:0.7;'></span>20 000 000</li>
  </ul>
</div>
</div>
</body>
</html>
<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""
macro = MacroElement()
macro._template = Template(template)
mapa.get_root().add_child(macro)
########## EXTRA LEGEND end
mapa.save("folium/cizinci_zeny_2005.html")
# mapa
print("HOTOVO")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-5c39bbf5fd40> in <module>
#     161 mapa.get_root().add_child(macro)
#     162 ########## EXTRA LEGEND end
# --> 163 mapa.save("folium/cizinci_zeny_2005.html")
#     164 # mapa
#     165 print("HOTOVO")
#
# /usr/local/lib/python3.7/dist-packages/branca/element.py in save(self, outfile, close_file, **kwargs)
#     164
#     165         root = self.get_root()
# --> 166         html = root.render(**kwargs)
#     167         fid.write(html.encode('utf8'))
#     168         if close_file:
#
# /usr/local/lib/python3.7/dist-packages/branca/element.py in render(self, **kwargs)
#     316         """Renders the HTML representation of the element."""
#     317         for name, child in self._children.items():
# --> 318             child.render(**kwargs)
# ...
